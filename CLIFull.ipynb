# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **Tải Ultralytics**

# %%
#tải ultralytics
# !pip install ultralytics

# %% [markdown]
# **Các bước Train Data**

# %%
#tạo file yaml
# !echo 'train: /content/drive/MyDrive/dataset/gun' >> mydataset.yaml
# !echo 'val: /content/drive/MyDrive/dataset/gun' >> mydataset.yaml
# !echo 'nc: 1' >> mydataset.yaml
# !echo "names: ['gun']" >> mydataset.yaml

# %%
#train với cli
# !yolo task=detect mode=train data=data/mydataset.yaml epochs=1 imgsz=640

# %%
#nhận diện dectection
# !yolo task=detect mode=predict model="/content/runs/detect/train/weights/best.pt" source="https://static.kinhtedothi.vn/w960/images/upload/2022/08/10/20220810-120753.jpg"

# %% [markdown]
# **Nhận dạng Detection**

# %%
#tải về dataset segmentation
# !wget https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt

# %%
#nhận diện dectection
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'

# %% [markdown]
# **Nhận dạng Segmentation**

# %%
#tải về dataset segmentation
# !wget https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n-seg.pt

# %%
#nhận diện segmentation
# !yolo task=segment mode=predict model=yolov8n-seg.pt source="https://nextcity.org/images/made/219951734_2838e034bb_o_840_630_80.jpg"
